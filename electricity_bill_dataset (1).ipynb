# %%
import pandas as pd
df =pd.read_csv("electricity_bill_dataset.csv")
df
# Out:
#        Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  \
# 0       16          23.0             2.0         6.0      1.0          0
# 1       19          22.0             2.0         3.0      1.0          0
# 2        7          20.0             2.0         6.0      7.0          0
# 3        7          22.0             3.0        21.0      1.0          0
# 4       11          23.0             2.0        11.0      1.0          0
# ...    ...           ...             ...         ...      ...        ...
# 45340   18          22.0             3.0        22.0      1.0          0
# 45341   23          23.0             2.0         6.0     12.0          0
# 45342   22          22.0             2.0        20.0      1.0          0
# 45343    8          21.0             2.0        22.0      7.0          0
# 45344    8          17.0             2.0         4.0      1.0          0
#
#        Month       City                                            Company  \
# ...

# %%
import pandas as pd


df =pd.read_csv("electricity_bill_dataset.csv")


print(df.head())
print("\nShape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
print("\nData Types:")
print(df.dtypes)
# Out:
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16          23.0             2.0         6.0      1.0          0     10
# 1   19          22.0             2.0         3.0      1.0          0      5
# 2    7          20.0             2.0         6.0      7.0          0      7
# 3    7          22.0             3.0        21.0      1.0          0      6
# 4   11          23.0             2.0        11.0      1.0          0      2
#
#         City                                    Company  MonthlyHours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    TariffRate  ElectricityBill
# 0         8.4           3225.6
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nBasic Statistics:")
display(df.describe())
# Out:
# Missing Values:
# Fan                0
# Refrigerator       0
# AirConditioner     0
# Television         0
# Monitor            0
# MotorPump          0
# Month              0
# City               0
# Company            0
# MonthlyHours       0
# TariffRate         0
# ElectricityBill    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Basic Statistics:
#                 Fan  Refrigerator  AirConditioner    Television       Monitor  \
# count  45345.000000  45345.000000    45345.000000  45345.000000  45345.000000
# mean      13.990694     21.705458        1.503959     12.502635      2.865057
# std        5.470816      1.672575        1.115482      5.756007      3.894933
# min        5.000000     17.000000        0.000000      3.000000      1.000000
# 25%        9.000000     22.000000        1.000000      7.000000      1.000000
# 50%       14.000000     22.000000        2.000000     13.000000      1.000000
# 75%       19.000000     23.000000        2.000000     17.000000      1.000000
# ...

# %%
# 1. Dataset Information
print("\n========== DATASET INFORMATION ==========")
df.info()


# 2. Number of Rows and Columns
print("\n========== SHAPE ==========")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])


# 3. Column Names
print("\n========== COLUMNS ==========")
print(df.columns.tolist())


# 4. Missing Values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())


# 5. Duplicate Values
print("\n========== DUPLICATES ==========")
print("Duplicate rows:", df.duplicated().sum())


# 6. Statistical Summary
print("\n========== STATISTICAL SUMMARY ==========")
print(df.describe())
# Out:
# ========== DATASET INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 45345 entries, 0 to 45344
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fan              45345 non-null  int64
#  1   Refrigerator     45345 non-null  float64
#  2   AirConditioner   45345 non-null  float64
#  3   Television       45345 non-null  float64
#  4   Monitor          45345 non-null  float64
#  5   MotorPump        45345 non-null  int64
#  6   Month            45345 non-null  int64
#  7   City             45345 non-null  str
#  8   Company          45345 non-null  str
#  9   MonthlyHours     45345 non-null  int64
#  10  TariffRate       45345 non-null  float64
#  11  ElectricityBill  45345 non-null  float64
# dtypes: float64(6), int64(4), str(2)
# memory usage: 4.2 MB
#
# ========== SHAPE ==========
# Rows: 45345
# Columns: 12
#
# ========== COLUMNS ==========
# ...

# %%
print("\n========== FIRST 10 ROWS ==========")
print(df.head(10))

print("\n========== LAST 10 ROWS ==========")
print(df.tail(10))
# Out:
# ========== FIRST 10 ROWS ==========
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16          23.0             2.0         6.0      1.0          0     10
# 1   19          22.0             2.0         3.0      1.0          0      5
# 2    7          20.0             2.0         6.0      7.0          0      7
# 3    7          22.0             3.0        21.0      1.0          0      6
# 4   11          23.0             2.0        11.0      1.0          0      2
# 5   13          22.0             0.0        18.0      1.0          0      6
# 6   23          22.0             3.0        20.0     12.0          0      5
# 7   22          23.0             0.0        21.0      1.0          0     12
# 8    8          20.0             2.0         8.0      1.0          0      8
# 9   10          23.0             0.0        18.0      7.0          0      1
#
#         City                                    Company  MonthlyHours  \
# ...

# %%
print("\n========== UNIQUE VALUES ==========")

for column in df.columns:
    print(column, ":", df[column].nunique())
# Out:
# ========== UNIQUE VALUES ==========
# Fan : 19
# Refrigerator : 7
# AirConditioner : 4
# Television : 20
# Monitor : 3
# MotorPump : 1
# Month : 12
# City : 16
# Company : 32
# MonthlyHours : 748
# TariffRate : 16
# ElectricityBill : 8122

# %%
print("\n========== DATA TYPES ==========")
print(df.dtypes)
# Out:
# ========== DATA TYPES ==========
# Fan                  int64
# Refrigerator       float64
# AirConditioner     float64
# Television         float64
# Monitor            float64
# MotorPump            int64
# Month                int64
# City                   str
# Company                str
# MonthlyHours         int64
# TariffRate         float64
# ElectricityBill    float64
# dtype: object

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Between Variables")
plt.show()

# %%
df_clean = df.copy()

print("Original Shape:", df_clean.shape)
# Out:
# Original Shape: (45345, 12)

# %%
df_clean.columns = (
    df_clean.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

print("Cleaned Columns:")
print(df_clean.columns.tolist())
# Out:
# Cleaned Columns:
# ['fan', 'refrigerator', 'airconditioner', 'television', 'monitor', 'motorpump', 'month', 'city', 'company', 'monthlyhours', 'tariffrate', 'electricitybill']

# %%
print("Duplicate rows before:", df_clean.duplicated().sum())
# Out:
# Duplicate rows before: 0

# %%
missing = df_clean.isnull().sum()

print("Missing Values:")
print(missing[missing > 0])
# Out:
# Missing Values:
# Series([], dtype: int64)

# %%
numeric_cols = df_clean.select_dtypes(include="number").columns

for col in numeric_cols:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
print("\nNegative Values:")

for col in numeric_cols:
    count = (df_clean[col] < 0).sum()
    if count > 0:
        print(col, ":", count)
# Out:
# Negative Values:

# %%
import matplotlib.pyplot as plt

for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    plt.boxplot(df_clean[col].dropna())
    plt.title(f"Boxplot - {col}")
    plt.ylabel(col)
    plt.show()

# %%
print("\n========== CLEAN DATA SUMMARY ==========")
print(df_clean.describe())
# Out:
# ========== CLEAN DATA SUMMARY ==========
#                 fan  refrigerator  airconditioner    television       monitor  \
# count  45345.000000  45345.000000    45345.000000  45345.000000  45345.000000
# mean      13.990694     21.705458        1.503959     12.502635      2.865057
# std        5.470816      1.672575        1.115482      5.756007      3.894933
# min        5.000000     17.000000        0.000000      3.000000      1.000000
# 25%        9.000000     22.000000        1.000000      7.000000      1.000000
# 50%       14.000000     22.000000        2.000000     13.000000      1.000000
# 75%       19.000000     23.000000        2.000000     17.000000      1.000000
# max       23.000000     23.000000        3.000000     22.000000     12.000000
#
#        motorpump         month  monthlyhours    tariffrate  electricitybill
# count    45345.0  45345.000000  45345.000000  45345.000000     45345.000000
# ...

# %%
print("\nOriginal Shape:", df.shape)
print("Cleaned Shape:", df_clean.shape)
# Out:
# Original Shape: (45345, 12)
# Cleaned Shape: (45345, 12)

# %%
df_clean.to_csv(
    r"E:\Ds Project\electricity_bill_dataset_cleaned.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
print(df_clean.columns.tolist())
# Out:
# ['fan', 'refrigerator', 'airconditioner', 'television', 'monitor', 'motorpump', 'month', 'city', 'company', 'monthlyhours', 'tariffrate', 'electricitybill']

# %%
print(df_clean.head())
# Out:
#    fan  refrigerator  airconditioner  television  monitor  motorpump  month  \
# 0   16          23.0             2.0         6.0      1.0          0     10
# 1   19          22.0             2.0         3.0      1.0          0      5
# 2    7          20.0             2.0         6.0      7.0          0      7
# 3    7          22.0             3.0        21.0      1.0          0      6
# 4   11          23.0             2.0        11.0      1.0          0      2
#
#         city                                    company  monthlyhours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    tariffrate  electricitybill
# 0         8.4           3225.6
# ...

# %%
print(df_clean.dtypes)
# Out:
# fan                  int64
# refrigerator       float64
# airconditioner     float64
# television         float64
# monitor            float64
# motorpump            int64
# month                int64
# city                   str
# company                str
# monthlyhours         int64
# tariffrate         float64
# electricitybill    float64
# dtype: object

# %%
print("========== ELECTRICITY BILL ==========")

print(df_clean["electricitybill"].describe())
# Out:
# ========== ELECTRICITY BILL ==========
# count    45345.000000
# mean      4311.771307
# std       1073.886406
# min        807.500000
# 25%       3556.800000
# 50%       4299.400000
# 75%       5038.800000
# max       8286.300000
# Name: electricitybill, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df_clean["electricitybill"], bins=30)

plt.title("Electricity Bill Distribution")
plt.xlabel("Electricity Bill")
plt.ylabel("Number of Records")

plt.show()

# %%
appliances = [
    "fan",
    "refrigerator",
    "airconditioner",
    "television",
    "monitor",
    "motorpump"
]

print("========== AVERAGE APPLIANCE VALUES ==========")

print(df_clean[appliances].mean())
# Out:
# ========== AVERAGE APPLIANCE VALUES ==========
# fan               13.990694
# refrigerator      21.705458
# airconditioner     1.503959
# television        12.502635
# monitor            2.865057
# motorpump          0.000000
# dtype: float64

# %%
plt.figure(figsize=(10,5))

df_clean[appliances].mean().plot(kind="bar")

plt.title("Average Appliance Usage")
plt.xlabel("Appliance")
plt.ylabel("Average Value")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df_clean["monthlyhours"],
    df_clean["electricitybill"]
)

plt.title("Monthly Hours vs Electricity Bill")
plt.xlabel("Monthly Hours")
plt.ylabel("Electricity Bill")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df_clean["tariffrate"],
    df_clean["electricitybill"]
)

plt.title("Tariff Rate vs Electricity Bill")
plt.xlabel("Tariff Rate")
plt.ylabel("Electricity Bill")

plt.show()

# %%
city_bill = (
    df_clean
    .groupby("city")["electricitybill"]
    .mean()
    .sort_values(ascending=False)
)

print(city_bill)
# Out:
# city
# Navi Mumbai    4782.820213
# Mumbai         4770.510330
# Pune           4689.806420
# Nagpur         4613.464808
# Chennai        4545.783769
# Kolkata        4505.428358
# New Delhi      4382.525983
# Hyderabad      4304.749211
# Gurgaon        4300.230577
# Noida          4201.300680
# Faridabad      4166.154168
# Ahmedabad      4045.516179
# Vadodara       4022.401543
# Shimla         3964.076331
# Dahej          3880.245870
# Ratnagiri      3807.397234
# Name: electricitybill, dtype: float64

# %%
plt.figure(figsize=(10,5))

city_bill.plot(kind="bar")

plt.title("Average Electricity Bill by City")
plt.xlabel("City")
plt.ylabel("Average Electricity Bill")

plt.xticks(rotation=45)

plt.show()

# %%
company_bill = (
    df_clean
    .groupby("company")["electricitybill"]
    .mean()
    .sort_values(ascending=False)
)

print(company_bill)
# Out:
# company
# Indowind Energy                                                       4371.806065
# KEC International                                                     4363.597989
# Kalpataru Power                                                       4362.641209
# Toshiba Transmission & Distribution Systems (India) Pvt. Ltd.         4358.371471
# Orient Green                                                          4346.189629
# Reliance Energy                                                       4339.059030
# Sterlite Power Transmission Ltd                                       4336.391078
# Torrent Power Ltd.                                                    4326.356381
# Neueon Towers / Sujana Towers Ltd.                                    4324.453620
# Guj Ind Power                                                         4324.300745
# SJVN Ltd.                                                             4323.703807
# ...

# %%
plt.figure(figsize=(10,5))

company_bill.plot(kind="bar")

plt.title("Average Electricity Bill by Company")
plt.xlabel("Company")
plt.ylabel("Average Electricity Bill")

plt.xticks(rotation=45)

plt.show()

# %%
month_bill = (
    df_clean
    .groupby("month")["electricitybill"]
    .mean()
)

print(month_bill)
# Out:
# month
# 1     4403.964784
# 2     3919.195462
# 3     4409.862445
# 4     4254.603439
# 5     4398.011479
# 6     4219.997220
# 7     4432.699030
# 8     4401.935753
# 9     4221.012469
# 10    4409.195557
# 11    4258.952020
# 12    4422.842174
# Name: electricitybill, dtype: float64

# %%
plt.figure(figsize=(10,5))

month_bill.plot(kind="line", marker="o")

plt.title("Monthly Electricity Bill Trend")
plt.xlabel("Month")
plt.ylabel("Average Electricity Bill")

plt.grid()

plt.show()

# %%
numeric_cols = df_clean.select_dtypes(include="number").columns

correlation = df_clean[numeric_cols].corr()

print(correlation["electricitybill"].sort_values(ascending=False))
# Out:
# electricitybill    1.000000
# monthlyhours       0.958702
# television         0.412651
# fan                0.410682
# refrigerator       0.376816
# monitor            0.309986
# tariffrate         0.286226
# airconditioner     0.261845
# month              0.036316
# motorpump               NaN
# Name: electricitybill, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(10,7))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
for appliance in appliances:

    plt.figure(figsize=(7,4))

    plt.scatter(
        df_clean[appliance],
        df_clean["electricitybill"]
    )

    plt.title(f"{appliance} vs Electricity Bill")
    plt.xlabel(appliance)
    plt.ylabel("Electricity Bill")

    plt.show()

# %%
high_bill = df_clean.sort_values(
    "electricitybill",
    ascending=False
)

print(high_bill.head(10))
# Out:
#        fan  refrigerator  airconditioner  television  monitor  motorpump  \
# 23282   18          23.0             3.0        22.0     12.0          0
# 44084   17          23.0             3.0        22.0     12.0          0
# 43577   23          23.0             3.0        19.0     12.0          0
# 38527   19          22.0             2.0        22.0     12.0          0
# 32433   22          23.0             2.0        22.0     12.0          0
# 10952   21          22.0             3.0        22.0     12.0          0
# 32365   22          23.0             3.0        19.0     12.0          0
# 34131   21          23.0             3.0        16.0     12.0          0
# 13838   23          23.0             3.0        14.0     12.0          0
# 28399   22          23.0             2.0        17.0     12.0          0
#
#        month         city                                            company  \
# 23282     11  Navi Mumbai                    Unitech Power Transmission Ltd.
# ...

# %%
low_bill = df_clean.sort_values(
    "electricitybill",
    ascending=True
)

print(low_bill.head(10))
# Out:
#        fan  refrigerator  airconditioner  television  monitor  motorpump  \
# 3480     5          17.0             0.0         3.0      1.0          0
# 2063     6          20.0             0.0         3.0      1.0          0
# 12115    8          18.0             0.0         3.0      1.0          0
# 32361    6          17.0             0.0         5.0      1.0          0
# 15747    8          17.0             0.0         3.0      1.0          0
# 39352    5          19.0             0.0         3.0      1.0          0
# 6939     7          17.0             1.0         3.0      1.0          0
# 44620    9          17.0             0.0         5.0      1.0          0
# 6432     7          17.0             0.0         6.0      1.0          0
# 34797    5          20.0             0.0         3.0      1.0          0
#
#        month         city                             company  monthlyhours  \
# 3480       2    New Delhi     L&T Transmission & Distribution            95
# ...

# %%
# Dashboard-ready dataset

dashboard_df = df_clean.copy()

# Check final data
print("Shape:", dashboard_df.shape)
print("\nColumns:")
print(dashboard_df.columns.tolist())

# Save dashboard data
dashboard_df.to_csv(
    r"E:\Ds Project\electricity_dashboard_data.csv",
    index=False
)

print("\nDashboard dataset saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Dashboard-ready dataset
#       2
# ----> 3 dashboard_df = df_clean.copy()
#       4
#       5 # Check final data
#       6 print("Shape:", dashboard_df.shape)
#
# NameError: name 'df_clean' is not defined

# %%
import pandas as pd

# Load original dataset
df = pd.read_csv("electricity_bill_dataset.csv")

# Create clean dataset
df_clean = df.copy()

# Clean column names
df_clean.columns = (
    df_clean.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# Remove duplicate rows
df_clean = df_clean.drop_duplicates()

# Fill missing numeric values with median
numeric_cols = df_clean.select_dtypes(include="number").columns

for col in numeric_cols:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# Fill missing categorical values with mode
categorical_cols = df_clean.select_dtypes(
    include=["object", "string", "category"]
).columns

for col in categorical_cols:
    if df_clean[col].isnull().any():
        df_clean[col] = df_clean[col].fillna(df_clean[col].mode()[0])

# Final check
print("Original Shape:", df.shape)
print("Cleaned Shape:", df_clean.shape)

print("\nColumns:")
print(df_clean.columns.tolist())

print("\nMissing Values:")
print(df_clean.isnull().sum())
# Out:
# Original Shape: (45345, 12)
# Cleaned Shape: (45345, 12)
#
# Columns:
# ['fan', 'refrigerator', 'airconditioner', 'television', 'monitor', 'motorpump', 'month', 'city', 'company', 'monthlyhours', 'tariffrate', 'electricitybill']
#
# Missing Values:
# fan                0
# refrigerator       0
# airconditioner     0
# television         0
# monitor            0
# motorpump          0
# month              0
# city               0
# company            0
# monthlyhours       0
# tariffrate         0
# electricitybill    0
# dtype: int64

# %%
dashboard_df = df_clean.copy()

dashboard_df.to_csv(
    "electricity_dashboard_data.csv",
    index=False
)

print("Dashboard dataset created successfully!")
print("Shape:", dashboard_df.shape)
# Out:
# Dashboard dataset created successfully!
# Shape: (45345, 12)

# %%
import os

print("Current Jupyter folder:")
print(os.getcwd())
# Out:
# Current Jupyter folder:
# C:\Users\Rishi

# %%
dashboard_df = df_clean.copy()

file_path = r"E:\Ds Project\electricity_dashboard_data.csv"

dashboard_df.to_csv(
    file_path,
    index=False
)

print("Dashboard file created successfully!")
print("File location:", file_path)
print("Shape:", dashboard_df.shape)
# Out:
# Dashboard file created successfully!
# File location: E:\Ds Project\electricity_dashboard_data.csv
# Shape: (45345, 12)

# %%
import os

file_path = r"E:\Ds Project\electricity_dashboard_data.csv"

if os.path.exists(file_path):
    print("✅ File exists!")
    print("File size:", os.path.getsize(file_path), "bytes")
else:
    print("❌ File not found")
# Out:
# ✅ File exists!
# File size: 3439989 bytes

# %%
dashboard_df = df_clean.copy()

file_path = r"E:\Ds Project\electricity_dashboard_data.csv"

dashboard_df.to_csv(
    file_path,
    index=False
)

print("Dashboard file created successfully!")
print("File location:", file_path)
print("Shape:", dashboard_df.shape)
# Out:
# Dashboard file created successfully!
# File location: E:\Ds Project\electricity_dashboard_data.csv
# Shape: (45345, 12)

# %%
appliance_summary = pd.DataFrame({
    "Appliance": [
        "Fan",
        "Refrigerator",
        "Air Conditioner",
        "Television",
        "Monitor",
        "Motor Pump"
    ],
    "Average Value": [
        df_clean["fan"].mean(),
        df_clean["refrigerator"].mean(),
        df_clean["airconditioner"].mean(),
        df_clean["television"].mean(),
        df_clean["monitor"].mean(),
        df_clean["motorpump"].mean()
    ]
})

print(appliance_summary)
# Out:
#          Appliance  Average Value
# 0              Fan      13.990694
# 1     Refrigerator      21.705458
# 2  Air Conditioner       1.503959
# 3       Television      12.502635
# 4          Monitor       2.865057
# 5       Motor Pump       0.000000

# %%
appliance_summary.to_csv(
    r"E:\Ds Project\appliance_summary.csv",
    index=False
)

# %%
# Features and target

X = df_clean.drop("electricitybill", axis=1)

y = df_clean["electricitybill"]

print("Features:")
print(X.columns.tolist())

print("\nTarget:")
print(y.name)

print("\nX Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# Features:
# ['fan', 'refrigerator', 'airconditioner', 'television', 'monitor', 'motorpump', 'month', 'city', 'company', 'monthlyhours', 'tariffrate']
#
# Target:
# electricitybill
#
# X Shape: (45345, 11)
# y Shape: (45345,)

# %%
numeric_features = [
    "fan",
    "refrigerator",
    "airconditioner",
    "television",
    "monitor",
    "motorpump",
    "monthlyhours",
    "tariffrate"
]

categorical_features = [
    "month",
    "city",
    "company"
]

print("Numerical:", numeric_features)
print("Categorical:", categorical_features)
# Out:
# Numerical: ['fan', 'refrigerator', 'airconditioner', 'television', 'monitor', 'motorpump', 'monthlyhours', 'tariffrate']
# Categorical: ['month', 'city', 'company']

# %%
from sklearn.model_selection import train_test_split

X = df_clean[numeric_features + categorical_features]
y = df_clean["electricitybill"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2
#       3 X = df_clean[numeric_features + categorical_features]
#       4 y = df_clean["electricitybill"]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

X = df_clean[numeric_features + categorical_features]
y = df_clean["electricitybill"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (36276, 11)
# Testing data: (9069, 11)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        (
            "categorical",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ],
    remainder="passthrough"
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

linear_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LinearRegression())
    ]
)

linear_model.fit(X_train, y_train)

print("Linear Regression model trained successfully!")
# Out:
# Linear Regression model trained successfully!

# %%
y_pred_linear = linear_model.predict(X_test)

print("Actual Bills:")
print(y_test.head().values)

print("\nPredicted Bills:")
print(y_pred_linear[:5])
# Out:
# Actual Bills:
# [5054.7 3809.2 3245.3 5728.8 4148. ]
#
# Predicted Bills:
# [5033.94788409 3856.53386523 3234.46506742 5724.95600106 4149.5801734 ]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_linear = mean_absolute_error(y_test, y_pred_linear)

mse_linear = mean_squared_error(y_test, y_pred_linear)

rmse_linear = np.sqrt(mse_linear)

r2_linear = r2_score(y_test, y_pred_linear)

print("Linear Regression Results")
print("-------------------------")
print("MAE :", mae_linear)
print("RMSE:", rmse_linear)
print("R²  :", r2_linear)
# Out:
# Linear Regression Results
# -------------------------
# MAE : 49.26346952309939
# RMSE: 70.55184030356928
# R²  : 0.9956314909458119

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            RandomForestRegressor(
                n_estimators=200,
                random_state=42
            )
        )
    ]
)

rf_model.fit(X_train, y_train)

print("Random Forest model trained successfully!")

# %%
y_pred_rf = rf_model.predict(X_test)

print("Actual Bills:")
print(y_test.head().values)

print("\nRandom Forest Predictions:")
print(y_pred_rf[:5])

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)

mse_rf = mean_squared_error(y_test, y_pred_rf)

rmse_rf = np.sqrt(mse_rf)

r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest Results")
print("---------------------")
print("MAE :", mae_rf)
print("RMSE:", rmse_rf)
print("R²  :", r2_rf)

# %%
model_comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest"
    ],
    "MAE": [
        mae_linear,
        mae_rf
    ],
    "RMSE": [
        rmse_linear,
        rmse_rf
    ],
    "R2": [
        r2_linear,
        r2_rf
    ]
})

model_comparison

# %%
if r2_rf > r2_linear:
    best_model = rf_model
    best_model_name = "Random Forest"
else:
    best_model = linear_model
    best_model_name = "Linear Regression"

print("Best Model:", best_model_name)

# %%
new_customer = pd.DataFrame({
    "fan": [2],
    "refrigerator": [1],
    "airconditioner": [1],
    "television": [2],
    "monitor": [1],
    "motorpump": [1],
    "month": ["July"],
    "city": ["Ahmedabad"],
    "company": ["ABC"],
    "monthlyhours": [250],
    "tariffrate": [7.5]
})

predicted_bill = best_model.predict(new_customer)

print("Predicted Electricity Bill:", predicted_bill[0])
